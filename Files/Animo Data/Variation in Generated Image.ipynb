# %% [markdown]
# # Load Libraries

# %%
import os
# os.getcwd()
# print(os.listdir())

# %%
import tensorflow
import numpy as np
from numpy import *
from numpy.random import *

# %% [markdown]
# # Plot Function

# %%
import matplotlib.pyplot as plt
def plot_image(x_input,n=4):
    plt.figure(figsize=(8,5))
    for i in range(n*n):
        plt.subplot(n, n, i+1)
        plt.imshow(x_input[i,:,:,:])
        plt.axis('off')
    plt.show()

# %% [markdown]
# # Load Generator Model

# %%
# load generator model
generator = tensorflow.keras.models.load_model("generator_model.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# # Generate Data One

# %%
def generate_latent_points(latent_dim, n_samples):
    x_input = randn(latent_dim * n_samples)
    z_input = x_input.reshape(n_samples, latent_dim)
    z = np.random.randint(0,7,size=(n_samples))
    print(z)
    return [z_input,z]

# %%
# generated images
latent_dim = 512
n_samples = 100
latent_points, labels = generate_latent_points(latent_dim= latent_dim, n_samples= n_samples)
pred  = generator.predict([latent_points, labels])
# Out:
# [4 0 5 4 0 4 4 3 4 4 3 5 4 2 1 4 5 6 1 3 4 4 5 0 4 0 1 6 2 3 4 0 5 2 2 6 0
#  2 0 3 6 1 5 0 0 5 3 6 3 5 2 3 4 6 0 2 1 0 5 0 6 0 2 0 2 6 0 1 4 3 4 1 3 4
#  4 3 1 6 2 0 0 0 4 0 3 5 6 5 5 4 5 3 6 6 4 5 5 5 1 0]
# 4/4 [==============================] - 2s 338ms/step

# %% [markdown]
# # Plot Generated Data One

# %%
# Generated images
X1 = pred[:100]
X1 = (X1 + 1)/2.0
plot_image(X1,n=6)

# %% [markdown]
# # Generate Data Two

# %%
def generate_latent_points(latent_dim, n_samples):
    x_input = randn(latent_dim * n_samples)
    z_input = x_input.reshape(n_samples, latent_dim)
    z = np.array([6 for i in range(n_samples)])
    print(z)
    return [z_input,z]

# %%
# generated images
latent_dim = 512
n_samples = 100
latent_points, labels = generate_latent_points(latent_dim= latent_dim, n_samples= n_samples)
pred  = generator.predict([latent_points, labels])
# Out:
# [6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6
#  6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6
#  6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6]
# 4/4 [==============================] - 1s 333ms/step

# %% [markdown]
# # Plot Generated Data Two

# %%
# Generated images
X1 = pred[:100]
X1 = (X1 + 1)/2.0
plot_image(X1,n=6)
